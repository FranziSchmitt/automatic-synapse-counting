# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os

import cv2

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# custom imports
from loading_data import load_data, crop_images, extract_voxel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-cf6332b0ea5c> in <module>
#      13
#      14 # custom imports
# ---> 15 from loading_data import load_data, crop_images, extract_voxel
#
# ModuleNotFoundError: No module named 'loading_data'

# %%
images, info = load_data(filepath='../Data/Atta/CG379_14_63xZ2_Ca_li/')

voxel_size, voxel_depth = extract_voxel(info)

cropped_sequence = crop_images(images, voxel_size=voxel_size)
# Out:
# 86.01632589865557

# %%
plt.imshow(cropped_sequence[1])

# %%
im = cropped_sequence[1].copy()
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,50,255,0)
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
contours[0][0][0]
# Out:
# array([ 9, 85], dtype=int32)

# %%
plt.contour(contours[0][0][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a8c7c365cc73> in <module>()
# ----> 1 plt.contour(contours[0][0][0])
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in contour(*args, **kwargs)
#    2774                       mplDeprecation)
#    2775     try:
# -> 2776         ret = ax.contour(*args, **kwargs)
#    2777     finally:
#    2778         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ...
